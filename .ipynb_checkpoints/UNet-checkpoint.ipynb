# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from scipy.ndimage.measurements import label
# %matplotlib inline

# %%
df = pd.read_csv('./object-dataset/labels.csv', 
                 delim_whitespace=True,
                 names=["img", "xmin", "ymin", "xmax", "ymax", "occluded", "label", "attribute"]
                )
df.head()
# Out:
#                        img  xmin  ymin  xmax  ymax  occluded       label  \
# 0  1478019952686311006.jpg   950   574  1004   620         0         car
# 1  1478019952686311006.jpg  1748   482  1818   744         0  pedestrian
# 2  1478019953180167674.jpg   872   586   926   632         0         car
# 3  1478019953689774621.jpg   686   566   728   618         1       truck
# 4  1478019953689774621.jpg   716   578   764   622         0         car
#
#   attribute
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df["img"] = "./object-dataset/" + df["img"]
df.head()
# Out:
#                                         img  xmin  ymin  xmax  ymax  occluded  \
# 0  ./object-dataset/1478019952686311006.jpg   950   574  1004   620         0
# 1  ./object-dataset/1478019952686311006.jpg  1748   482  1818   744         0
# 2  ./object-dataset/1478019953180167674.jpg   872   586   926   632         0
# 3  ./object-dataset/1478019953689774621.jpg   686   566   728   618         1
# 4  ./object-dataset/1478019953689774621.jpg   716   578   764   622         0
#
#         label attribute
# 0         car       NaN
# 1  pedestrian       NaN
# 2         car       NaN
# 3       truck       NaN
# 4         car       NaN

# %%
def get_boxes(img_path, df):
    boxes = []
    subset = df[df["img"] == img_path]
    for index, row in subset.iterrows():
        boxes.append(((row["xmin"], row["ymin"]), (row["xmax"], row["ymax"])))
    return boxes

def show_img(row, df): 
#     print(row["label"])
    img_path = row["img"]
    img = mpimg.imread(img_path)
    boxes = get_boxes(img_path, df)
    for box in boxes:
        img = cv2.rectangle(img, box[0], box[1], (255,0,0), 2)
    plt.figure(figsize=(20,10))
    plt.imshow(img)

# row = df.iloc[97]  #97 & 98
show_img(df.iloc[293], df)

# %%
dfcar = df[df["label"]=="car"].reset_index(drop=True)

dfcar.head()
# Out:
#                                         img  xmin  ymin  xmax  ymax  occluded  \
# 0  ./object-dataset/1478019952686311006.jpg   950   574  1004   620         0
# 1  ./object-dataset/1478019953180167674.jpg   872   586   926   632         0
# 2  ./object-dataset/1478019953689774621.jpg   716   578   764   622         0
# 3  ./object-dataset/1478019953689774621.jpg   826   580   880   626         0
# 4  ./object-dataset/1478019953689774621.jpg  1540   488  1680   608         1
#
#   label attribute
# 0   car       NaN
# 1   car       NaN
# 2   car       NaN
# 3   car       NaN
# 4   car       NaN

# %%
show_img(dfcar.iloc[171], dfcar)

# %%
from keras.models import Model
from keras.layers import Input, Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers.merge import Concatenate
from keras.layers.advanced_activations import ThresholdedReLU
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
#appromximate dice coefficient
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def getModel():
    inputs = Input((None, None, 3))
    
    conv1 = Convolution2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Convolution2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv2 = Convolution2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Convolution2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Convolution2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Convolution2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    conv4 = Convolution2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Convolution2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    
    conv5 = Convolution2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Convolution2D(512, (3, 3), activation='relu', padding='same')(conv5)
#     pool5 = MaxPooling2D(pool_size=(2, 2))(conv5)
    
#     conv6 = Convolution2D(1024, (3, 3), activation='relu', padding='same')(pool5)
#     conv6 = Convolution2D(1024, (3, 3), activation='relu', padding='same')(conv6)
#     pool6 = MaxPooling2D(pool_size=(2, 2))(conv6)
    
    up4 = Concatenate()([UpSampling2D(size=(2,2))(conv5), conv4])
    upconv4 = Convolution2D(256, (3,3), activation='relu', padding='same')(up4)
    upconv4 = Convolution2D(256, (3,3), activation='relu', padding='same')(upconv4)
    
    up3 = Concatenate()([UpSampling2D(size=(2,2))(upconv4), conv3])
    upconv3 = Convolution2D(128, (3,3), activation='relu', padding='same')(up3)
    upconv3 = Convolution2D(128, (3,3), activation='relu', padding='same')(upconv3)
    
    up2 = Concatenate()([UpSampling2D(size=(2,2))(upconv3), conv2])
    upconv2 = Convolution2D(64, (3,3), activation='relu', padding='same')(up2)
    upconv2 = Convolution2D(64, (3,3), activation='relu', padding='same')(upconv2)
    
    up1 = Concatenate()([UpSampling2D(size=(2,2))(upconv2), conv1])
    upconv1 = Convolution2D(32, (3,3), activation='relu', padding='same')(up1)
    upconv1 = Convolution2D(32, (3,3), activation='relu', padding='same')(upconv1)
    
    upconv1 = Convolution2D(1, (1, 1), activation='sigmoid')(upconv1)
#     upconv1 = Convolution2D(1, (1, 1))(upconv2)
    upconv1 = ThresholdedReLU(theta=0.90)(upconv1)
    
    
    adam = Adam(lr=1e-5)
    model = Model(inputs=inputs, outputs=upconv1)
    
    model.compile(optimizer=adam, loss=dice_coef_loss, metrics=[dice_coef])
    return model


model = getModel()
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_13 (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# conv2d_193 (Conv2D)          (None, None, None, 32)    896
# _________________________________________________________________
# conv2d_194 (Conv2D)          (None, None, None, 32)    9248
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, None, None, 32)    0
# _________________________________________________________________
# conv2d_195 (Conv2D)          (None, None, None, 64)    18496
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, None, None, 64)    36928
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, None, None, 64)    0
# _________________________________________________________________
# conv2d_197 (Conv2D)          (None, None, None, 128)   73856
# _________________________________________________________________
# conv2d_198 (Conv2D)          (None, None, None, 128)   147584
# _________________________________________________________________
# max_pooling2d_51 (MaxPooling (None, None, None, 128)   0
# _________________________________________________________________
# conv2d_199 (Conv2D)          (None, None, None, 256)   295168
# _________________________________________________________________
# conv2d_200 (Conv2D)          (None, None, None, 256)   590080
# _________________________________________________________________
# max_pooling2d_52 (MaxPooling (None, None, None, 256)   0
# _________________________________________________________________
# conv2d_201 (Conv2D)          (None, None, None, 512)   1180160
# _________________________________________________________________
# conv2d_202 (Conv2D)          (None, None, None, 512)   2359808
# _________________________________________________________________
# up_sampling2d_37 (UpSampling (None, None, None, 512)   0
# _________________________________________________________________
# concatenate_37 (Concatenate) (None, None, None, 768)   0
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, None, None, 256)   1769728
# _________________________________________________________________
# conv2d_204 (Conv2D)          (None, None, None, 256)   590080
# _________________________________________________________________
# up_sampling2d_38 (UpSampling (None, None, None, 256)   0
# _________________________________________________________________
# concatenate_38 (Concatenate) (None, None, None, 384)   0
# _________________________________________________________________
# conv2d_205 (Conv2D)          (None, None, None, 128)   442496
# _________________________________________________________________
# conv2d_206 (Conv2D)          (None, None, None, 128)   147584
# _________________________________________________________________
# up_sampling2d_39 (UpSampling (None, None, None, 128)   0
# _________________________________________________________________
# concatenate_39 (Concatenate) (None, None, None, 192)   0
# _________________________________________________________________
# conv2d_207 (Conv2D)          (None, None, None, 64)    110656
# _________________________________________________________________
# conv2d_208 (Conv2D)          (None, None, None, 64)    36928
# _________________________________________________________________
# up_sampling2d_40 (UpSampling (None, None, None, 64)    0
# _________________________________________________________________
# concatenate_40 (Concatenate) (None, None, None, 96)    0
# _________________________________________________________________
# conv2d_209 (Conv2D)          (None, None, None, 32)    27680
# _________________________________________________________________
# conv2d_210 (Conv2D)          (None, None, None, 32)    9248
# _________________________________________________________________
# conv2d_211 (Conv2D)          (None, None, None, 1)     33
# _________________________________________________________________
# thresholded_re_lu_9 (Thresho (None, None, None, 1)     0
# =================================================================
# Total params: 7,846,657.0
# Trainable params: 7,846,657.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
def plot_xy(x, y):
    f, ax = plt.subplots(1, 2, figsize=(16,10))
    ax[0].imshow(x)
    ax[0].set_title('X', fontsize=20)
    ax[1].imshow(y)
    ax[1].set_title('Y', fontsize=20)

def get_segment(x, boxes):
    mask = np.zeros(x.shape[0:2])
    for box in boxes:
        mask = cv2.rectangle(mask, box[0], box[1], (1,0,0), -1)
    return mask

row = dfcar.iloc[170]
x = mpimg.imread(row["img"])
y = get_segment(x, get_boxes(row["img"], dfcar))

plot_xy(x, y)

# %%
from random import randint

def generator(df, batch_size=1):
    while 1:
        x_sample = []
        y_sample = []
        for i in range(batch_size):
            item = randint(0,9)
            row = df.iloc[170+item]
            img_path= row["img"]
            x = mpimg.imread(img_path)
            y = get_segment(x, get_boxes(img_path, df))
#             x = cv2.resize(x, (1280, 800), interpolation=cv2.INTER_AREA)
#             y = cv2.resize(y, (1280, 800), interpolation=cv2.INTER_AREA)
            y = y[:, :, np.newaxis]
            x_sample.append(x)
            y_sample.append(y)
        yield np.stack(x_sample), np.stack(y_sample)
        

g = generator(dfcar)

x, y = next(g)
index = 0
print(x.shape, y.shape)
print(x[index].shape, y[index].shape)

z = x[index].copy()
z[y[index].squeeze()==0]=0
plot_xy(x[index], z)
# Out:
# (1, 1200, 1920, 3) (1, 1200, 1920, 1)
# (1200, 1920, 3) (1200, 1920, 1)

# %%
train_generator = generator(dfcar)
history = model.fit_generator(train_generator, steps_per_epoch= 20, epochs=30)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 11s - loss: -0.7485 - dice_coef: 0.7485
# Epoch 2/30
# 20/20 [==============================] - 9s - loss: -0.8710 - dice_coef: 0.8710
# Epoch 3/30
# 20/20 [==============================] - 9s - loss: -0.8817 - dice_coef: 0.8817
# Epoch 4/30
# 20/20 [==============================] - 9s - loss: -0.8638 - dice_coef: 0.8638
# Epoch 5/30
# 20/20 [==============================] - 9s - loss: -0.8900 - dice_coef: 0.8900
# Epoch 6/30
# 20/20 [==============================] - 9s - loss: -0.9072 - dice_coef: 0.9072
# Epoch 7/30
# 20/20 [==============================] - 9s - loss: -0.9369 - dice_coef: 0.9369
# Epoch 8/30
# 20/20 [==============================] - 9s - loss: -0.9260 - dice_coef: 0.9260
# Epoch 9/30
# 20/20 [==============================] - 10s - loss: -0.9380 - dice_coef: 0.9380
# Epoch 10/30
# 20/20 [==============================] - 9s - loss: -0.9471 - dice_coef: 0.9471
# Epoch 11/30
# 20/20 [==============================] - 9s - loss: -0.9427 - dice_coef: 0.9427
# Epoch 12/30
# 20/20 [==============================] - 9s - loss: -0.9249 - dice_coef: 0.9249
# Epoch 13/30
# 20/20 [==============================] - 9s - loss: -0.9299 - dice_coef: 0.9299
# Epoch 14/30
# 20/20 [==============================] - 9s - loss: -0.9490 - dice_coef: 0.9490
# Epoch 15/30
# 20/20 [==============================] - 9s - loss: -0.9538 - dice_coef: 0.9538
# Epoch 16/30
# 20/20 [==============================] - 9s - loss: -0.9535 - dice_coef: 0.9535
# Epoch 17/30
# 20/20 [==============================] - 9s - loss: -0.9599 - dice_coef: 0.9599
# Epoch 18/30
# 20/20 [==============================] - 9s - loss: -0.9679 - dice_coef: 0.9679
# Epoch 19/30
# 20/20 [==============================] - 9s - loss: -0.9710 - dice_coef: 0.9710
# Epoch 20/30
# 20/20 [==============================] - 9s - loss: -0.9707 - dice_coef: 0.9707
# Epoch 21/30
# 20/20 [==============================] - 9s - loss: -0.9677 - dice_coef: 0.9677
# Epoch 22/30
# 20/20 [==============================] - 9s - loss: -0.9448 - dice_coef: 0.9448
# Epoch 23/30
# 20/20 [==============================] - 9s - loss: -0.9745 - dice_coef: 0.9745
# Epoch 24/30
# 20/20 [==============================] - 9s - loss: -0.9731 - dice_coef: 0.9731
# Epoch 25/30
# 20/20 [==============================] - 9s - loss: -0.9791 - dice_coef: 0.9791
# Epoch 26/30
# 20/20 [==============================] - 9s - loss: -0.9758 - dice_coef: 0.9758
# Epoch 27/30
# 20/20 [==============================] - 9s - loss: -0.9657 - dice_coef: 0.9657
# Epoch 28/30
# 20/20 [==============================] - 9s - loss: -0.9776 - dice_coef: 0.9776
# Epoch 29/30
# 20/20 [==============================] - 9s - loss: -0.9728 - dice_coef: 0.9728
# Epoch 30/30
# 20/20 [==============================] - 9s - loss: -0.9726 - dice_coef: 0.9726

# %%
### Save weights 
model.save("UNet.h5")
model.save_weights("UNet_weights.h5", overwrite=True)

# %%
model.load_weights("UNet_weights.h5")

# %%
print(history.history.keys())

### plot the training and validation loss for each epoch
plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.title('model IOU loss')
plt.ylabel('IOU loss')
plt.xlabel('epoch')
plt.legend(['training set', 'validation set'], loc='upper right')
plt.show()
# Out:
# dict_keys(['loss', 'dice_coef'])

# %%
g = generator(dfcar)
x, y = next(g)
index = 0
test_img = x[index]
test_img = cv2.resize(test_img, (1280, 800), interpolation=cv2.INTER_AREA)
test_img = test_img[None, :, :, :]

# %time prediction = model.predict(test_img)[0]
z = test_img.squeeze().copy()
# z = cv2.bitwise_and(z, z, mask=prediction)
z[prediction.squeeze()<0.9]=0
print(prediction.shape)
plot_xy(x[index], z)

figure = plt.figure(figsize=(20,12))
plt.imshow(z)
# Out:
# CPU times: user 132 ms, sys: 28 ms, total: 160 ms
# Wall time: 128 ms
# (800, 1280, 1)

# %%
print(prediction.shape)

labels = label(prediction[:,:,0])
print(labels[0].shape)

for object_no in range(1, labels[1]+1):
    # Find pixels with each car_number label value
    nonzero = (labels[0] == car_number).nonzero()
    # Identify x and y values of those pixels
    nonzeroy = np.array(nonzero[0])
    nonzerox = np.array(nonzero[1])
    


figure = plt.figure(figsize=(20,12))
# plt.imshow(labels, cmap='gray')
# Out:
# (800, 1280, 1)
# (800, 1280)
